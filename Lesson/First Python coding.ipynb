# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
y=[3,6,-3,9,-7,4]

# %%
plt.plot(y)

# %%
x=[0, 0.7, np.sqrt(2), np.pi, 8, 9]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
np.linspace()
