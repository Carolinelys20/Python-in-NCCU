# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
x=np.linspace(0,20,1000)
y=np.sin(x)
z=np.cos(x)

fig=plt.figure(figsize=(16,12))
axes3d=Axes3D(fig)

axes3d.plot(x,y,z,lw=5)
